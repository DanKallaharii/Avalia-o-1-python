# %% [markdown]
# <a href="https://colab.research.google.com/github/DanKallaharii/Avalia-o-1-python/blob/main/C%C3%B3pia_de_Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.core.interactiveshell import inspect
class Funcionario:
  def __init__(self,nome,setor,cargo):
    self.nome = nome
    self.setor = setor
    self.cargo = cargo

  def __str__(self):
    return f"Ola meu nome é {self.nome} trabalho no Atacadão Dia Dia no setor de {self.setor} no cargo de {self.cargo}"

funcionario1 = Funcionario("Eduardo","bebidas","Repositor")
print(funcionario1)
# Out:
# Ola meu nome é Eduardo trabalho no Atacadão Dia Dia no setor de bebidas no cargo de Repositor
